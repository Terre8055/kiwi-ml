# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
pd.set_option('display.max_rows', 85)

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
df.head(10)
# Out:
#    ResponseId     Q120                                         MainBranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# ...

# %%
df.Knowledge_2
# Out:
# 0                               NaN
# 1                             Agree
# 2        Neither agree nor disagree
# 3                 Strongly disagree
# 4                    Strongly agree
#                     ...
# 89179                           NaN
# 89180                           NaN
# 89181                           NaN
# 89182                           NaN
# 89183    Neither agree nor disagree
# Name: Knowledge_2, Length: 89184, dtype: object

# %%
kn = df[['Knowledge_2']]

# %%
kn
# Out:
#                       Knowledge_2
# 0                             NaN
# 1                           Agree
# 2      Neither agree nor disagree
# 3               Strongly disagree
# 4                  Strongly agree
# ...                           ...
# 89179                         NaN
# 89180                         NaN
# 89181                         NaN
# 89182                         NaN
# 89183  Neither agree nor disagree
#
# [89184 rows x 1 columns]

# %%
d_series = [1,2,4]

# %%
n = df['Knowledge_2']

# %%
n
# Out:
# 0                               NaN
# 1                             Agree
# 2        Neither agree nor disagree
# 3                 Strongly disagree
# 4                    Strongly agree
#                     ...
# 89179                           NaN
# 89180                           NaN
# 89181                           NaN
# 89182                           NaN
# 89183    Neither agree nor disagree
# Name: Knowledge_2, Length: 89184, dtype: object

# %%
type(n)
# Out:
# pandas.core.series.Series

# %%
df.iloc[0,0]
# Out:
# np.int64(1)

# %%
u = df.iloc[0,0]

# %%
u = df.iloc[5, 5]

# %%
u
# Out:
# 'Remote'

# %%
df.loc[5, 'Knowledge_2']
# Out:
# 'Strongly agree'

# %%
df.iloc[15:18, 15:18]
# Out:
#                 PurchaseInfluence      TechList  \
# 15          I have some influence   Investigate
# 16          I have some influence  Given a list
# 17  I have little or no influence           NaN
#
#                                            BuyNewTool
# 15  Start a free trial;Ask developers I know/work ...
# 16  Start a free trial;Ask developers I know/work ...
# 17  Start a free trial;Ask developers I know/work ...

# %%
pd
# Out:
# <module 'pandas' from '/Users/mike/DataScienceLab/base/lib/python3.12/site-packages/pandas/__init__.py'>

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
a = np.array([1,2,3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.dtype
# Out:
# dtype('int64')

# %%
c = a[:2]

# %%
c
# Out:
# array([1, 2])

# %%
da = [1,3,5]

# %%
da[0],da[1] = 20,70

# %%
da
# Out:
# [20, 70, 5]

# %%
arr = np.array([1, 2, 3, 4, 5, 6, 7])

# %%
arr[1:5:2]
# Out:
# array([2, 4])

# %%
arr.size
# Out:
# 7

# %%
len(arr)
# Out:
# 7

# %%
pass

# %%
sum(arr)
# Out:
# np.int64(28)

# %%
for i in arr:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
arr.ndim
# Out:
# 1

# %% [raw]
# pass

# %%
gtY = np.array([1,2,60,7,8])

# %%
gtY.shape
# Out:
# (5,)

# %%
gtY.ndim
# Out:
# 1

# %%
arr.mean()
# Out:
# np.float64(4.0)

# %%
int(arr.mean())
# Out:
# 4

# %%
std = arr.std()

# %%
std
# Out:
# np.float64(2.0)

# %%
gty = gtY

# %%
gty
# Out:
# array([ 1,  2, 60,  7,  8])

# %%
pass

# %%
u = np.array([1,0])

# %%
v = np.array([0,1])

# %%
u + v
# Out:
# array([1, 1])

# %%
pass

# %%
z = np.add(u, v)

# %%
z
# Out:
# array([1, 1])

# %% [raw]
# import sys

# %%
import time

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
def Plotvec1(u, z, v):
    
    ax = plt.axes() # to generate the full window axes
    ax.arrow(0, 0, *u, head_width=0.05, color='r', head_length=0.1)# Add an arrow to the  U Axes with arrow head width 0.05, color red and arrow head length 0.1
    plt.text(*(u + 0.1), 'u')#Adds the text u to the Axes 
    
    ax.arrow(0, 0, *v, head_width=0.05, color='b', head_length=0.1)# Add an arrow to the  v Axes with arrow head width 0.05, color red and arrow head length 0.1
    plt.text(*(v + 0.1), 'v')#Adds the text v to the Axes 
    
    ax.arrow(0, 0, *z, head_width=0.05, head_length=0.1)
    plt.text(*(z + 0.1), 'z')#Adds the text z to the Axes 
    plt.ylim(-2, 2)#set the ylim to bottom(-2), top(2)
    plt.xlim(-2, 2)#set the xlim to left(-2), right(2)

# %%
Plotvec1(u, z, v)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
X=np.array([[1,0],[0,1]]) 

Y=np.array([[0,1],[1,0]]) 

Z=X+Y

# %%
Z
# Out:
# array([[1, 1],
#        [1, 1]])

# %%
X=np.array([[1,0,1],[2,2,2]]) 

out=X[0:2,2]

# %%
out
# Out:
# array([1, 2])

# %%
X=np.array([[1,0],[0,1]])

Y=np.array([[2,2],[2,2]]) 

Z=np.dot(X,Y)

# %%
Z
# Out:
# array([[2, 2],
#        [2, 2]])

# %%
dir(np)
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_get_promotion_state',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_no_nep50_warning',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_set_promotion_state',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
# ...

# %%
np.nan
# Out:
# nan

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=89184, step=1)

# %%
df.to_numpy()
# Out:
# array([[1, 'I agree', 'None of these', ..., nan, nan, nan],
#        [2, 'I agree', 'I am a developer by profession', ...,
#         'Appropriate in length', 'Easy', 285000.0],
#        [3, 'I agree', 'I am a developer by profession', ...,
#         'Appropriate in length', 'Easy', 250000.0],
#        ...,
#        [89182, 'I agree', 'I code primarily as a hobby', ..., 'Too long',
#         'Neither easy nor difficult', nan],
#        [89183, 'I agree', 'I am a developer by profession', ...,
#         'Appropriate in length', 'Neither easy nor difficult', nan],
#        [89184, 'I agree', 'I am a developer by profession', ...,
#         'Appropriate in length', 'Easy', nan]], dtype=object)

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
df.T
# Out:
#                                                0      \
# ResponseId                                         1
# Q120                                         I agree
# MainBranch                             None of these
# Age                                  18-24 years old
# Employment                                       NaN
# RemoteWork                                       NaN
# CodingActivities                                 NaN
# EdLevel                                          NaN
# LearnCode                                        NaN
# LearnCodeOnline                                  NaN
# LearnCodeCoursesCert                             NaN
# YearsCode                                        NaN
# YearsCodePro                                     NaN
# DevType                                          NaN
# OrgSize                                          NaN
# PurchaseInfluence                                NaN
# TechList                                         NaN
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
c1 = df[['Knowledge_2']]

# %%
c1
# Out:
#                       Knowledge_2
# 0                             NaN
# 1                           Agree
# 2      Neither agree nor disagree
# 3               Strongly disagree
# 4                  Strongly agree
# ...                           ...
# 89179                         NaN
# 89180                         NaN
# 89181                         NaN
# 89182                         NaN
# 89183  Neither agree nor disagree
#
# [89184 rows x 1 columns]

# %%
c2 = df.iloc[5:10,10]

# %%
c2
# Out:
# 5                                     Other
# 6                                     Udemy
# 7                            Codecademy;edX
# 8                         Udemy;Pluralsight
# 9    edX;Udemy;Pluralsight;Coursera;Udacity
# Name: LearnCodeCoursesCert, dtype: object

# %%
df.fillna('Hi')
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                 Hi
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.drop_duplicates()
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %% [markdown]
# ## Lets explore the various types of numpy

# %% [markdown]
# > Sugar

# %%
new_file = df.to_csv('data/new_data', index=False)

# %%
new_file

# %%
new_data = pd.read_csv('data/new_data')

# %%
new_data
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
nd = new_data

# %%
nd.mean(numeric_only=True)
# Out:
# ResponseId             4.459250e+04
# CompTotal              1.036807e+42
# WorkExp                1.140513e+01
# ConvertedCompYearly    1.031101e+05
# dtype: float64

# %%
nd.dtypes
# Out:
# ResponseId                               int64
# Q120                                    object
# MainBranch                              object
# Age                                     object
# Employment                              object
# RemoteWork                              object
# CodingActivities                        object
# EdLevel                                 object
# LearnCode                               object
# LearnCodeOnline                         object
# LearnCodeCoursesCert                    object
# YearsCode                               object
# YearsCodePro                            object
# DevType                                 object
# OrgSize                                 object
# PurchaseInfluence                       object
# TechList                                object
# BuyNewTool                              object
# Country                                 object
# Currency                                object
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# ...

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.loc[3]
# Out:
# ResponseId                                                                             4
# Q120                                                                             I agree
# MainBranch                                                I am a developer by profession
# Age                                                                      25-34 years old
# Employment                                                           Employed, full-time
# RemoteWork                                          Hybrid (some remote, some in-person)
# CodingActivities                                                                   Hobby
# EdLevel                                     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LearnCode                              Colleague;Friend or family member;Other online...
# LearnCodeOnline                        Formal documentation provided by the owner of ...
# ...

# %%
df.iloc[3]
# Out:
# ResponseId                                                                             4
# Q120                                                                             I agree
# MainBranch                                                I am a developer by profession
# Age                                                                      25-34 years old
# Employment                                                           Employed, full-time
# RemoteWork                                          Hybrid (some remote, some in-person)
# CodingActivities                                                                   Hobby
# EdLevel                                     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LearnCode                              Colleague;Friend or family member;Other online...
# LearnCodeOnline                        Formal documentation provided by the owner of ...
# ...

# %%
df.loc[4]
# Out:
# ResponseId                                                                             5
# Q120                                                                             I agree
# MainBranch                                                I am a developer by profession
# Age                                                                      25-34 years old
# Employment                             Employed, full-time;Independent contractor, fr...
# RemoteWork                                                                        Remote
# CodingActivities                       Hobby;Contribute to open-source projects;Profe...
# EdLevel                                     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LearnCode                              Books / Physical media;Online Courses or Certi...
# LearnCodeOnline                        Formal documentation provided by the owner of ...
# ...

# %%
df.iloc[4]
# Out:
# ResponseId                                                                             5
# Q120                                                                             I agree
# MainBranch                                                I am a developer by profession
# Age                                                                      25-34 years old
# Employment                             Employed, full-time;Independent contractor, fr...
# RemoteWork                                                                        Remote
# CodingActivities                       Hobby;Contribute to open-source projects;Profe...
# EdLevel                                     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# LearnCode                              Books / Physical media;Online Courses or Certi...
# LearnCodeOnline                        Formal documentation provided by the owner of ...
# ...

# %%
df['YearsCodePro']
# Out:
# 0        NaN
# 1          9
# 2         23
# 3          7
# 4          4
#         ...
# 89179      5
# 89180    NaN
# 89181    NaN
# 89182    NaN
# 89183     12
# Name: YearsCodePro, Length: 89184, dtype: object

# %%
df.fillna(0)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                  0
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df["YearsCodePro"].describe()
# Out:
# count     66136
# unique       52
# top           5
# freq       4792
# Name: YearsCodePro, dtype: object

# %%
df["YearsCodePro"].fillna(0)
# Out:
# 0         0
# 1         9
# 2        23
# 3         7
# 4         4
#          ..
# 89179     5
# 89180     0
# 89181     0
# 89182     0
# 89183    12
# Name: YearsCodePro, Length: 89184, dtype: object

# %%
# yrs_exp = df["YearsCodePro"].astype('int64')?\
new_df = df.fillna(0)

# %%
new_df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                  0
# 1         25-34 years old                                Employed, full-time
# ...

# %%
pd.crosstab(df["YearsCode"], df["Knowledge_2"])
# Out:
# Knowledge_2  Agree  Disagree  Neither agree nor disagree  Strongly agree  \
# YearsCode
# 0               35        21                          40              13
# 1               59        38                          66              17
# 2              154       102                         180              60
# 3              290       237                         326             104
# 4              400       269                         377             128
# 5              547       439                         606             205
# 6              581       481                         587             222
# 7              661       502                         588             250
# 8              794       508                         641             300
# 9              598       344                         413             218
# 10            1115       756                         861             417
# 11             459       333                         365             197
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87435 entries, 1 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           87435 non-null  int64
#  1   Q120                                 87435 non-null  object
#  2   MainBranch                           87435 non-null  object
#  3   Age                                  87435 non-null  object
#  4   Employment                           87375 non-null  object
#  5   RemoteWork                           73432 non-null  object
#  6   CodingActivities                     73398 non-null  object
#  7   EdLevel                              87435 non-null  object
#  8   LearnCode                            87238 non-null  object
#  9   LearnCodeOnline                      69849 non-null  object
#  10  LearnCodeCoursesCert                 36951 non-null  object
# ...

# %%
df['YearsCode'].plot()
# Out:
# <Axes: >

# %%
df['Knowledge_1'].str.lower()
# Out:
# 1        strongly agree
# 2        strongly agree
# 3        strongly agree
# 4                 agree
# 5                 agree
#               ...
# 89179               NaN
# 89180               NaN
# 89181               NaN
# 89182               NaN
# 89183             agree
# Name: Knowledge_1, Length: 87435, dtype: object

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# 5               6  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 1         25-34 years old                                Employed, full-time
# 2         45-54 years old                                Employed, full-time
# ...

# %%
country_counts = df["Country"].value_counts()

# %%
usa_count = country_counts.get("United States of America", 0)

# %%
usa_count
country_counts
# Out:
# Country
# United States of America                                18561
# Germany                                                  7302
# India                                                    5533
# United Kingdom of Great Britain and Northern Ireland     5532
# Canada                                                   3492
#                                                         ...
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Saint Vincent and the Grenadines                            1
# Name: count, Length: 185, dtype: int64

# %%
# Out:
# 'Mike'
